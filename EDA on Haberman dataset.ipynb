# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
haberman= pd.read_csv(r"C:\Users\KHUSHI\Documents\Python Scripts\haberman.csv")
haberman
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 300   74    63      0       1
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
#
# [305 rows x 4 columns]

# %%
survival=haberman.loc[haberman["status"]==1];
death=haberman.loc[haberman["status"]==2];

# %%
sns.FacetGrid(haberman,hue="status",height=5) \
   .map(sns.distplot,"age") \
   .add_legend();
plt.show()

# %%
sns.FacetGrid(haberman,hue="status",height=5) \
   .map(sns.distplot,"year") \
   .add_legend();
plt.show()

# %%
sns.FacetGrid(haberman,hue="status",height=5) \
   .map(sns.distplot,"nodes") \
   .add_legend();
plt.show()

# %%
counts,bin_edges=np.histogram(survival['age'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts,bin_edges=np.histogram(death['age'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.05333333 0.10666667 0.12444444 0.09333333 0.16444444 0.16444444
#  0.09333333 0.11111111 0.06222222 0.02666667]
# [30.  34.7 39.4 44.1 48.8 53.5 58.2 62.9 67.6 72.3 77. ]
# [0.0375 0.075  0.2125 0.1125 0.2    0.1    0.0875 0.1125 0.0375 0.025 ]
# [34.  38.4 42.8 47.2 51.6 56.  60.4 64.8 69.2 73.6 78. ]

# %%
counts,bin_edges=np.histogram(survival['year'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts,bin_edges=np.histogram(death['year'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.18666667 0.10666667 0.10222222 0.07111111 0.09777778 0.10222222
#  0.06666667 0.09777778 0.09333333 0.07555556]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# [0.25   0.05   0.0375 0.0875 0.1    0.1    0.1625 0.075  0.05   0.0875]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]

# %%
counts,bin_edges=np.histogram(survival['nodes'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts,bin_edges=np.histogram(death['nodes'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# [0.5625 0.15   0.1375 0.05   0.075  0.     0.0125 0.     0.     0.0125]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %%
sns.boxplot(x="status",y="age",data=haberman)
plt.show()

# %%
sns.boxplot(x="status",y="year",data=haberman)
plt.show()

# %%
sns.boxplot(x="status",y="nodes",data=haberman)
plt.show()

# %%
sns.violinplot(x="status",y="age",data=haberman,size=10)
plt.show()

# %%
sns.violinplot(x="status",y="year",data=haberman,size=10)
plt.show()

# %%
sns.violinplot(x="status",y="nodes",data=haberman,size=10)
plt.show()

# %%
haberman.plot(kind='scatter',x='age',y='year');
plt.show()

# %%
haberman.plot(kind='scatter',x='age',y='nodes');
plt.show()

# %%
haberman.plot(kind='scatter',y='nodes',x='year');
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(haberman,hue="status",height=8) \
   .map(plt.scatter, "age","year") \
   .add_legend();
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(haberman,hue="status",height=8) \
   .map(plt.scatter, "age","nodes") \
   .add_legend();
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(haberman,hue="status",height=8) \
   .map(plt.scatter, "year","nodes") \
   .add_legend();
plt.show()

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(haberman,hue="status",height=3);
plt.show()
# Out:
# C:\Users\KHUSHI\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\KHUSHI\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
plt.plot(survival["age"],np.zeros_like(survival['age']))
plt.plot(death["age"],np.zeros_like(death['age']))
plt.show()

# %%
plt.plot(survival["year"],np.zeros_like(survival['year']))
plt.plot(death["year"],np.zeros_like(death['year']))
plt.show()

# %%
plt.plot(survival["nodes"],np.zeros_like(survival['nodes']))
plt.plot(death["nodes"],np.zeros_like(death['nodes']))
plt.show()
